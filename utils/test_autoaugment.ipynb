# %%
from autoaugment import ImageNetPolicy
from PIL import Image

image = Image.open('../cloud_dataset/images/00012346c7664a2a9c58750ba10e7a7c.jpg')
policy = ImageNetPolicy()
transformed = policy(image)
# Out:
# <PIL.Image.Image image mode=RGB size=792x792 at 0x7F320CB92170>

# %%
transformed
# Out:
# <PIL.Image.Image image mode=RGB size=792x792>
